# %%
import pandas as pd
import numpy as np
import datetime

# %%
data = pd.read_excel('data.xlsx',sheet_name = 'Операции по счету')

# %%
data
# Out:
#               ACCT      SINCE      DEBIT    CREDIT     BALANCE
# 0    123СЧЕТСБЕРAA 2017-09-25   62573.12      0.00    62573.12
# 1    123СЧЕТСБЕРAA 2017-09-26     462.96  63036.08        0.00
# 2    123СЧЕТСБЕРAA 2017-09-27     141.67      0.00      141.67
# 3    123СЧЕТСБЕРAA 2017-09-28     141.67    283.34        0.00
# 4    123СЧЕТСБЕРAA 2017-10-25   69444.44      0.00    69444.44
# ..             ...        ...        ...       ...         ...
# 451  123СЧЕТСБЕРCC 2018-08-20  308641.97      0.00  1234567.88
# 452  123СЧЕТСБЕРCC 2018-09-20  308641.97      0.00  1543209.85
# 453  123СЧЕТСБЕРCC 2018-10-22  308641.97      0.00  1851851.82
# 454  123СЧЕТСБЕРCC 2018-11-20  308641.97      0.00  2160493.79
# 455  123СЧЕТСБЕРCC 2018-12-27  308642.01      0.00  2469135.80
#
# [456 rows x 5 columns]

# %%
acct = data['ACCT']
since = data['SINCE']
debit = data['DEBIT']
credit = data['CREDIT']
balance = data['BALANCE']
#######################
chet_sber_123СЧЕТСБЕРAA = '123СЧЕТСБЕРAA'
chet_sber_123СЧЕТСБЕРBB = '123СЧЕТСБЕРBB'
chet_sber_123СЧЕТСБЕРCC = '123СЧЕТСБЕРCC'
#######################
count_sep_2017 = 0
count_oct_2017 = 0
count_nov_2017 = 0
count_dec_2017 = 0
count_jan_2017 = 0
count_feb_2017 = 0
count_mar_2017 = 0
count_apr_2017 = 0
count_may_2017 = 0
count_jun_2017 = 0
count_jul_2017 = 0
count_aug_2017 = 0
#########################
count_sep_2018 = 0
count_oct_2018 = 0
count_nov_2018 = 0
count_dec_2018 = 0
count_jan_2018 = 0
count_feb_2018 = 0
count_mar_2018 = 0
count_apr_2018= 0
count_may_2018= 0
count_jun_2018= 0
count_jul_2018 = 0
count_aug_2018 = 0
#########################
count_sep_2017_sberb_bb = 0
count_oct_2017_sberb_bb = 0
count_nov_2017_sberb_bb = 0
count_dec_2017_sberb_bb = 0
count_jan_2017_sberb_bb = 0
count_feb_2017_sberb_bb = 0
count_mar_2017_sberb_bb = 0
count_apr_2017_sberb_bb = 0
count_may_2017_sberb_bb = 0
count_jun_2017_sberb_bb = 0
count_jul_2017_sberb_bb = 0
count_aug_2017_sberb_bb = 0
#########################
count_sep_2018_sberb_bb = 0
count_oct_2018_sberb_bb = 0
count_nov_2018_sberb_bb = 0
count_dec_2018_sberb_bb = 0
count_jan_2018_sberb_bb = 0
count_feb_2018_sberb_bb = 0
count_mar_2018_sberb_bb = 0
count_apr_2018_sberb_bb = 0
count_may_2018_sberb_bb = 0
count_jun_2018_sberb_bb = 0
count_jul_2018_sberb_bb = 0
count_aug_2018_sberb_bb = 0
#########################
count_sep_2017_sberb_cc = 0
count_oct_2017_sberb_cc = 0
count_nov_2017_sberb_cc = 0
count_dec_2017_sberb_cc = 0
count_jan_2017_sberb_cc = 0
count_feb_2017_sberb_cc = 0
count_mar_2017_sberb_cc = 0
count_apr_2017_sberb_cc = 0
count_may_2017_sberb_cc = 0
count_jun_2017_sberb_cc = 0
count_jul_2017_sberb_cc = 0
count_aug_2017_sberb_cc = 0
#########################
count_sep_2018_sberb_cc = 0
count_oct_2018_sberb_cc = 0
count_nov_2018_sberb_cc = 0
count_dec_2018_sberb_cc = 0
count_jan_2018_sberb_cc = 0
count_feb_2018_sberb_cc = 0
count_mar_2018_sberb_cc = 0
count_apr_2018_sberb_cc = 0
count_may_2018_sberb_cc = 0
count_jun_2018_sberb_cc = 0
count_jul_2018_sberb_cc = 0
count_aug_2018_sberb_cc = 0
#########################
year_2017 = 2017
year_2018 = 2018
#########################

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_sep_2017 = count_sep_2017 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_sep_2017 = count_sep_2017 + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2017} , {count_sep_2017} дня просрочки:')


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_oct_2017 = count_oct_2017 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_oct_2017 = count_oct_2017 + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2017} , {count_oct_2017} дня просрочки:')

print('Важный момент!, программа не смогла определить не достающие дни, аудит должен в excel файле указать все дни, за октябрь указано от 25.10.2017 по 27.10.2017 и резко на 30.10.2017  а где 28,29 дни, должно быть 7 дней просрочки за октябрь(2017) но вышло только 4 дня, по скольку не хватает указанных дней (28,29  резки переход с 27 на 30)')

#Важный момент!, программа не смогла определить не достающие дни, аудит должен в excel файле
#указать все дни, за октябрь указано от 25.10.2017 по 27.10.2017
#и резко на 30.10.2017б а где 28,29 дни, должно быть 7 дней просрочки за октябрь(2017)
#но вышло только 4 дня, по скольку не хватает указанных дней (28,29)

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_nov_2017 = count_nov_2017 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_nov_2017 = count_nov_2017 + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2017} , {count_nov_2017} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_dec_2017 = count_dec_2017 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_dec_2017 = count_dec_2017 + 1
        print(t)
print(f'За декабрь {chet_sber_123СЧЕТСБЕРAA} , {year_2017} , {count_dec_2017} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 1) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jan_2018 = count_jan_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 1) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jan_2018 = count_jan_2018 + 1
print(f'За январь {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_jan_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 2) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_feb_2018 = count_feb_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 2) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_feb_2018 = count_feb_2018 + 1
print(f'За февраль {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_feb_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 3) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_mar_2018 = count_mar_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 3) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_mar_2018 = count_mar_2018 + 1
print(f'За март {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_mar_2018} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 4) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_apr_2018 = count_apr_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 4) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_apr_2018 = count_apr_2018 + 1
print(f'За апрель {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_apr_2018} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 5) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_may_2018 = count_may_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 5) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_may_2018 = count_may_2018 + 1
print(f'За май {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_may_2018} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 6) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jun_2018 = count_jun_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 6) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jun_2018 = count_jun_2018 + 1
print(f'За июнь {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_jun_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 7) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jul_2018 = count_jul_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 7) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jul_2018 = count_jul_2018 + 1
print(f'За июль {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_jul_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 8) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_aug_2018 = count_aug_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 8) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_aug_2018 = count_aug_2018 + 1
print(f'За август {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_aug_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_sep_2018 = count_sep_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_sep_2018 = count_sep_2018 + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_sep_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_oct_2018 = count_oct_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_oct_2018 = count_oct_2018 + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_oct_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_nov_2018 = count_nov_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_nov_2018 = count_nov_2018 + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРAA} , {year_2018} , {count_nov_2018} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРAA') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_dec_2018 = count_dec_2018 + 1
    if (i == '123СЧЕТСБЕРAA') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_dec_2018 = count_dec_2018 + 1
print(f'За декабрь {chet_sber_123СЧЕТСБЕРAA} ,{year_2018} , {count_dec_2018} дней просрочки:')

print('######################################################')

##########################################################################################


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_sep_2017_sberb_bb = count_sep_2017_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_sep_2017_sberb_bb = count_sep_2017_sberb_bb + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2017} , {count_sep_2017_sberb_bb} дня просрочки:')


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_oct_2017_sberb_bb = count_oct_2017_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_oct_2017_sberb_bb = count_oct_2017_sberb_bb + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2017} , {count_oct_2017_sberb_bb} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_nov_2017_sberb_bb = count_nov_2017_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_nov_2017_sberb_bb = count_nov_2017_sberb_bb + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2017} , {count_nov_2017_sberb_bb} дня просрочки:')


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_dec_2017_sberb_bb = count_dec_2017_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_dec_2017_sberb_bb = count_dec_2017_sberb_bb + 1
        print(t)
print(f'За декабрь {chet_sber_123СЧЕТСБЕРBB} , {year_2017} , {count_dec_2017_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 1) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jan_2018_sberb_bb = count_jan_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 1) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jan_2018_sberb_bb = count_jn_2018_sberb_bb + 1
print(f'За январь {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_jan_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 2) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_feb_2018_sberb_bb = count_feb_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 2) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_feb_2018_sberb_bb = count_feb_2018_sberb_bb + 1
print(f'За февраль {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_feb_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 3) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_mar_2018_sberb_bb = count_mar_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 3) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_mar_2018_sberb_bb = count_mar_2018_sberb_bb + 1
print(f'За март {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_mar_2018_sberb_bb} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 4) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_apr_2018_sberb_bb = count_apr_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 4) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_apr_2018_sberb_bb = count_apr_2018_sberb_bb + 1
print(f'За апрель {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_apr_2018_sberb_bb} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 5) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_may_2018_sberb_bb = count_may_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 5) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_may_2018_sberb_bb = count_may_2018_sberb_bb + 1
print(f'За май {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_may_2018_sberb_bb} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 6) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jun_2018_sberb_bb = count_jun_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 6) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jun_2018_sberb_bb = count_jun_2018_sberb_bb + 1
print(f'За июнь {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_jun_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 7) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jul_2018_sberb_bb = count_jul_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 7) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jul_2018_sberb_bb = count_jul_2018_sberb_bb + 1
print(f'За июль {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_jul_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 8) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_aug_2018_sberb_bb = count_aug_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 8) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_aug_2018_sberb_bb = count_aug_2018_sberb_bb + 1
print(f'За август {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_aug_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_sep_2018_sberb_bb = count_sep_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_sep_2018_sberb_bb = count_sep_2018_sberb_bb + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_sep_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_oct_2018_sberb_bb = count_oct_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_oct_2018_sberb_bb = count_oct_2018_sberb_bb + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_oct_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_nov_2018_sberb_bb = count_nov_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_nov_2018_sberb_bb = count_nov_2018_sberb_bb + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРBB} , {year_2018} , {count_nov_2018_sberb_bb} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРBB') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_dec_2018_sberb_bb = count_dec_2018_sberb_bb + 1
    if (i == '123СЧЕТСБЕРBB') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_dec_2018_sberb_bb = count_dec_2018_sberb_bb + 1
print(f'За декабрь {chet_sber_123СЧЕТСБЕРBB} ,{year_2018} , {count_dec_2018_sberb_bb} дней просрочки:')

print('############################################################')



for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_sep_2017_sberb_cc = count_sep_2017_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_sep_2017_sberb_cc = count_sep_2017_sberb_cc + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2017} , {count_sep_2017_sberb_cc} дня просрочки:')


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_oct_2017_sberb_cc = count_oct_2017_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_oct_2017_sberb_cc = count_oct_2017_sberb_cc + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2017} , {count_oct_2017_sberb_cc} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_nov_2017_sberb_cc = count_nov_2017_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_nov_2017_sberb_cc = count_nov_2017_sberb_cc + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2017} , {count_nov_2017_sberb_cc} дня просрочки:')


for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2017):  
        count_dec_2017_sberb_cc = count_dec_2017_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2017):
        count_dec_2017_sberb_cc = count_dec_2017_sberb_cc + 1
        print(t)
print(f'За декабрь {chet_sber_123СЧЕТСБЕРCC} , {year_2017} , {count_dec_2017_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 1) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jan_2018_sberb_cc = count_jan_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 1) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jan_2018_sberb_cc = count_jan_2018_sberb_cc + 1
print(f'За январь {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_jan_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 2) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_feb_2018_sberb_cc = count_feb_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 2) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_feb_2018_sberb_cc = count_feb_2018_sberb_cc + 1
print(f'За февраль {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_feb_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 3) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_mar_2018_sberb_cc = count_mar_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 3) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_mar_2018_sberb_cc = count_mar_2018_sberb_cc + 1
print(f'За март {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_mar_2018_sberb_cc} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 4) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_apr_2018_sberb_cc = count_apr_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 4) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_apr_2018_sberb_cc = count_apr_2018_sberb_cc + 1
print(f'За апрель {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_apr_2018_sberb_cc} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 5) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_may_2018_sberb_cc = count_may_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 5) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_may_2018_sberb_cc = count_may_2018_sberb_cc + 1
print(f'За май {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_may_2018_sberb_cc} дня просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 6) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jun_2018_sberb_cc = count_jun_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 6) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jun_2018_sberb_cc = count_jun_2018_sberb_cc + 1
print(f'За июнь {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_jun_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 7) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_jul_2018_sberb_cc = count_jul_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 7) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_jul_2018_sberb_cc = count_jul_2018_sberb_cc + 1
print(f'За июль {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_jul_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 8) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_aug_2018_sberb_cc = count_aug_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 8) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_aug_2018_sberb_cc = count_aug_2018_sberb_cc + 1
print(f'За август {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_aug_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 9) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_sep_2018_sberb_cc = count_sep_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 9) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_sep_2018_sberb_cc = count_sep_2018_sberb_cc + 1
print(f'За сентябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_sep_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 10) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_oct_2018_sberb_cc = count_oct_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 10) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_oct_2018_sberb_cc = count_oct_2018_sberb_cc + 1
print(f'За октябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_oct_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 11) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_nov_2018_sberb_cc = count_nov_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 11) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_nov_2018_sberb_cc = count_nov_2018_sberb_cc + 1
print(f'За ноябрь {chet_sber_123СЧЕТСБЕРCC} , {year_2018} , {count_nov_2018_sberb_cc} дней просрочки:')

for i, j , k, z, t in zip(acct, since, credit, balance, since):
    if (i == '123СЧЕТСБЕРCC') and (j.month == 12) and (k == 0.00) and (z != 0.00) and (t.year == 2018):  
        count_dec_2018_sberb_cc = count_dec_2018_sberb_cc + 1
    if (i == '123СЧЕТСБЕРCC') and (j.month == 12) and (k != 0.00) and (z == 0.00) and (t.year == 2018):
        count_dec_2018_sberb_cc = count_dec_2018_sberb_cc + 1
print(f'За декабрь {chet_sber_123СЧЕТСБЕРCC} ,{year_2018} , {count_dec_2018_sberb_cc} дней просрочки:')
# Out:
# За сентябрь 123СЧЕТСБЕРAA , 2017 , 4 дня просрочки:
# За октябрь 123СЧЕТСБЕРAA , 2017 , 4 дня просрочки:
# Важный момент!, программа не смогла определить не достающие дни, аудит должен в excel файле указать все дни, за октябрь указано от 25.10.2017 по 27.10.2017 и резко на 30.10.2017  а где 28,29 дни, должно быть 7 дней просрочки за октябрь(2017) но вышло только 4 дня, по скольку не хватает указанных дней (28,29  резки переход с 27 на 30)
# За ноябрь 123СЧЕТСБЕРAA , 2017 , 22 дня просрочки:
# За декабрь 123СЧЕТСБЕРAA , 2017 , 19 дней просрочки:
# За январь 123СЧЕТСБЕРAA , 2018 , 20 дней просрочки:
# За февраль 123СЧЕТСБЕРAA , 2018 , 8 дней просрочки:
# За март 123СЧЕТСБЕРAA , 2018 , 0 дня просрочки:
# За апрель 123СЧЕТСБЕРAA , 2018 , 0 дня просрочки:
# За май 123СЧЕТСБЕРAA , 2018 , 4 дня просрочки:
# За июнь 123СЧЕТСБЕРAA , 2018 , 21 дней просрочки:
# За июль 123СЧЕТСБЕРAA , 2018 , 20 дней просрочки:
# За август 123СЧЕТСБЕРAA , 2018 , 21 дней просрочки:
# ...

# %%
new_data_frame = pd.DataFrame({'СЧЕТ': [chet_sber_123СЧЕТСБЕРAA, chet_sber_123СЧЕТСБЕРBB, chet_sber_123СЧЕТСБЕРCC],
                              'count_sep_2017 ':[count_sep_2017  ,count_sep_2017_sberb_bb ,count_sep_2017_sberb_cc  ],
                              'count_oct_2017 ':[count_oct_2017  ,count_oct_2017_sberb_bb ,count_oct_2017_sberb_cc  ], 
                              'count_nov_2017 ':[count_nov_2017  ,count_nov_2017_sberb_bb ,count_nov_2017_sberb_cc  ],
                              'count_dec_2017 ':[count_dec_2017  ,count_dec_2017_sberb_bb ,count_dec_2017_sberb_cc  ],
                              'count_jan_2018 ':[count_jan_2018  ,count_jan_2018_sberb_bb ,count_jan_2018_sberb_cc  ],
                              'count_feb_2018 ':[count_feb_2018  ,count_feb_2018_sberb_bb ,count_feb_2018_sberb_cc  ],
                              'count_apr_2018 ':[count_mar_2018  ,count_mar_2018_sberb_bb ,count_mar_2018_sberb_cc  ],
                              'count_may_2018 ':[count_apr_2018  ,count_apr_2018_sberb_bb ,count_apr_2018_sberb_cc  ],
                              'count_jun_2018 ':[count_jun_2018  ,count_jun_2018_sberb_bb ,count_jun_2018_sberb_cc  ],
                              'count_jul_2018 ':[count_jul_2018  ,count_jul_2018_sberb_bb ,count_jul_2018_sberb_cc  ],
                              'count_aug_2018 ':[count_aug_2018  ,count_aug_2018_sberb_bb ,count_aug_2018_sberb_cc  ],
                              'count_sep_2018 ':[count_sep_2018  ,count_sep_2018_sberb_bb ,count_sep_2018_sberb_cc  ],
                              'count_oct_2018 ':[count_oct_2018  ,count_oct_2018_sberb_bb ,count_oct_2018_sberb_cc  ],
                              'count_nov_2018 ':[count_nov_2018  ,count_nov_2018_sberb_bb ,count_nov_2018_sberb_cc  ],
                              'count_dec_2018 ':[count_dec_2018  ,count_dec_2018_sberb_bb ,count_dec_2018_sberb_cc  ],                   
                              })

# %%
new_data_frame
# Out:
#             СЧЕТ  count_sep_2017   count_oct_2017   count_nov_2017   \
# 0  123СЧЕТСБЕРAA                4                4               22
# 1  123СЧЕТСБЕРBB                0                1               10
# 2  123СЧЕТСБЕРCC                0                1                2
#
#    count_dec_2017   count_jan_2018   count_feb_2018   count_apr_2018   \
# 0               19               20                8                0
# 1               19               20                8                0
# 2                1                1                3                0
#
#    count_may_2018   count_jun_2018   count_jul_2018   count_aug_2018   \
# 0                0               21               20               21
# 1                2               21               20               21
# 2                2                1                1                1
#
#    count_sep_2018   count_oct_2018   count_nov_2018   count_dec_2018
# ...

# %%
new_data_frame.to_excel(r'C:\Users\Erkin\Desktop\pythonC\new_data_frame.xlsx', index = False)
